# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
import numpy as np

# %%
ab=pd.read_csv("netflix_titles.csv")
ab
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
ab.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
ab.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
ab.shape
# Out:
# (8807, 12)

# %%
ab.iloc[3600:3605]
# Out:
#      show_id     type                              title  \
# 3600   s3601  TV Show                               GLOW
# 3601   s3602  TV Show                            IZombie
# 3602   s3603    Movie            Jaoon Kahan Bata Ae Dil
# 3603   s3604    Movie  Rocko's Modern Life: Static Cling
# 3604   s3605  TV Show                           Sintonia
#
#                         director  \
# 3600                         NaN
# 3601                         NaN
# 3602             Aadish Keluskar
# 3603  Joe Murray, Cosmo Segurson
# 3604                         NaN
#
#                                                    cast        country  \
# 3600  Alison Brie, Betty Gilpin, Marc Maron, Britney...  United States
# 3601  Rose McIver, Malcolm Goodwin, Rahul Kohli, Rob...  United States
# 3602  Khushboo Upadhyay, Rohit Kokate, Himanshu Kohl...          India
# 3603  Carlos Alazraqui, Tom Kenny, Charlie Adler, Ji...  United States
# ...

# %%
ab['rating'].value_counts()
# Out:
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: rating, dtype: int64

# %%
ab['rating'].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
ab['type'].value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %%
listed_in = ab['listed_in'].value_counts()
print(listed_in.to_string())
# Out:
# Dramas, International Movies                                                       362
# Documentaries                                                                      359
# Stand-Up Comedy                                                                    334
# Comedies, Dramas, International Movies                                             274
# Dramas, Independent Movies, International Movies                                   252
# Kids' TV                                                                           220
# Children & Family Movies                                                           215
# Children & Family Movies, Comedies                                                 201
# Documentaries, International Movies                                                186
# Dramas, International Movies, Romantic Movies                                      180
# Comedies, International Movies                                                     176
# ...

# %%
mode_im = ['date_added','rating','duration']
for i in mode_im:
    ab[i] = ab[i].fillna(ab[i].mode()[0])

# %%
ab.drop(['show_id','date_added','description'],axis='columns', inplace= True)
ab.isnull().sum()
# Out:
# type                0
# title               0
# director         2634
# cast              825
# country           831
# release_year        0
# rating              0
# duration            0
# listed_in           0
# overall_infos       0
# dtype: int64

# %%
ab.head(20)
# Out:
#        type                                              title  \
# 0     Movie                               Dick Johnson Is Dead
# 1   TV Show                                      Blood & Water
# 2   TV Show                                          Ganglands
# 3   TV Show                              Jailbirds New Orleans
# 4   TV Show                                       Kota Factory
# 5   TV Show                                      Midnight Mass
# 6     Movie                   My Little Pony: A New Generation
# 7     Movie                                            Sankofa
# 8   TV Show                      The Great British Baking Show
# 9     Movie                                       The Starling
# 10  TV Show                Vendetta: Truth, Lies and The Mafia
# 11  TV Show                                   Bangkok Breaking
# 12    Movie                                       Je Suis Karl
# 13    Movie                   Confessions of an Invisible Girl
# ...

# %%
plt.figure(figsize=(6,6))
colors = ["tab:red","tab:blue"]
sns.countplot(x ='type', data = ab ,palette=colors )
plt.title("No Of Movies vs TV Shows")
plt.show()

# %%
plt.figure(figsize=(10,10))
y = sns.countplot(y='country',
            data=ab, order =ab['country'].value_counts().index[:15])

plt.tick_params(labelsize=10)
plt.title("Country With Most Released")
plt.show()

# %%
# analyze the distribution of shows/movies in different countries using bar plots
country_counts = ab['country'].value_counts()

plt.figure(figsize=(12, 6))
country_counts[:10].plot(kind='bar', color='blue')
plt.title('Top 10 Movie/Show Counts per Country on Netflix')
plt.xlabel('Country')
plt.ylabel('Number of Shows/Movies')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
release_year_counts = ab['release_year'].value_counts().sort_index()

plt.figure(figsize=(12, 6))
plt.scatter(release_year_counts.index, release_year_counts.values, marker='o')
plt.title('Number of Shows/Movies Released Over the Years')
plt.xlabel('Release Year')
plt.ylabel('Number of Shows/Movies')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# analyze the distribution of different genres using bar plots
genre_counts = ab['listed_in'].value_counts()

plt.figure(figsize=(12, 6))
genre_counts[:10].plot(kind='bar', color='purple')
plt.title('Top 10 Genres on Netflix')
plt.xlabel('Genres')
plt.ylabel('Number of Shows/Movies')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
labels = ["Movies", "TV Show"]
size = ab["type"].value_counts()
colors = plt.cm.Wistia(np.linspace(0,1,2))
explode= [0, 0.2]
plt.rcParams["figure.figsize"] = (5,5)
plt.pie(size,labels = labels, colors= colors, explode = explode, shadow= True, startangle=15,autopct="%1.2f")
plt.title("Distribution of Movies and TV Shows", fontsize=15)
plt.legend()
plt.show()

# %%
ab[(ab['type']=='TV Show') & (ab['country']=='United States')]
# Out:
#          type                                   title director  \
# 15    TV Show                       Dear White People      NaN
# 40    TV Show  He-Man and the Masters of the Universe      NaN
# 55    TV Show                               Nailed It      NaN
# 67    TV Show                       Saved by the Bell      NaN
# 82    TV Show                                 Lucifer      NaN
# ...       ...                                     ...      ...
# 8710  TV Show                                   Weeds      NaN
# 8726  TV Show                    When Calls the Heart      NaN
# 8747  TV Show                               Winsanity      NaN
# 8755  TV Show                       Women Behind Bars      NaN
# 8780  TV Show                            Yo-Kai Watch      NaN
#
#                                                    cast        country  \
# 15    Logan Browning, Brandon P. Bell, DeRon Horton,...  United States
# ...

# %%
top_countries = ab["country"].value_counts().head(5)
sns.barplot(x = top_countries.index, y = top_countries.values)
plt.xticks(rotation=75)
plt.title("5 Countries That Produce The Most Content")
plt.show()

# %%
rate = ab["rating"].value_counts()
sns.barplot(x = rate.index, y = rate.values)
plt.xticks(rotation=90)
plt.title("Rating")
plt.show()

# %%
plt.figure(figsize =(10,8))
sns.countplot(x = "rating", hue = "type", data=ab)
plt.title("Ratings by Type")
plt.show()

# %%
ab
# Out:
#          type                  title         director  \
# 0       Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1     TV Show          Blood & Water              NaN
# 2     TV Show              Ganglands  Julien Leclercq
# 3     TV Show  Jailbirds New Orleans              NaN
# 4     TV Show           Kota Factory              NaN
# ...       ...                    ...              ...
# 8802    Movie                 Zodiac    David Fincher
# 8803  TV Show            Zombie Dumb              NaN
# 8804    Movie             Zombieland  Ruben Fleischer
# 8805    Movie                   Zoom     Peter Hewitt
# 8806    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# ...

# %%
ab.sort_values(by= "release_year", ascending= True).reset_index().head()
# Out:
#    index     type                                          title  \
# 0   4250  TV Show              Pioneers: First Women Filmmakers*
# 1   7790    Movie                                 Prelude to War
# 2   8205    Movie                           The Battle of Midway
# 3   8660    Movie  Undercover: How to Operate Behind Enemy Lines
# 4   8739    Movie             Why We Fight: The Battle of Russia
#
#                       director                       cast        country  \
# 0                          NaN                        NaN            NaN
# 1                  Frank Capra                        NaN  United States
# 2                    John Ford  Henry Fonda, Jane Darwell  United States
# 3                    John Ford                        NaN  United States
# 4  Frank Capra, Anatole Litvak                        NaN  United States
#
#    release_year rating  duration                      listed_in  \
# 0          1925  TV-14  1 Season                       TV Shows
# ...

# %%
plt.hist(ab["release_year"], bins = 10, alpha = 0.5,
         color="blue", label = "Distribution of Data by Years")
plt.legend()
plt.show()

# %%
ab.nsmallest(1,'release_year').reset_index()
# Out:
#    index     type                              title director cast country  \
# 0   4250  TV Show  Pioneers: First Women Filmmakers*      NaN  NaN     NaN
#
#    release_year rating  duration listed_in  \
# 0          1925  TV-14  1 Season  TV Shows
#
#                                        overall_infos
# 0  TV Show Pioneers: First Women Filmmakers* nan ...

# %%
ab.nlargest(1,'release_year').reset_index()
# Out:
#    index     type          title director  \
# 0      1  TV Show  Blood & Water      NaN
#
#                                                 cast       country  \
# 0  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
#
#    release_year rating   duration  \
# 0          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0  International TV Shows, TV Dramas, TV Mysteries
#
#                                        overall_infos
# 0  TV Show Blood & Water nan Ama Qamata, Khosi Ng...

# %%
ab[(ab['type'] == 'Movie') & (ab['listed_in'] == 'Dramas')].head(3)
# Out:
#       type               title             director  \
# 112  Movie               Worth       Sara Colangelo
# 129  Movie  An Unfinished Life      Lasse Hallström
# 142  Movie     Freedom Writers  Richard LaGravenese
#
#                                                   cast  \
# 112  Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129  Robert Redford, Jennifer Lopez, Morgan Freeman...
# 142  Hilary Swank, Patrick Dempsey, Scott Glenn, Im...
#
#                     country  release_year rating duration listed_in  \
# 112                     NaN          2021  PG-13  119 min    Dramas
# 129  Germany, United States          2005  PG-13  108 min    Dramas
# 142  Germany, United States          2007  PG-13  124 min    Dramas
#
#                                          overall_infos
# 112  Movie Worth Sara Colangelo Michael Keaton, Sta...
# 129  Movie An Unfinished Life Lasse Hallström Rober...
# 142  Movie Freedom Writers Richard LaGravenese Hila...

# %%
drama_movies = ab[(ab['type'] == 'Movie') & (ab['listed_in'] == 'Dramas')]
drama_movies.reset_index().head(2)
# Out:
#    index   type               title         director  \
# 0    112  Movie               Worth   Sara Colangelo
# 1    129  Movie  An Unfinished Life  Lasse Hallström
#
#                                                 cast                 country  \
# 0  Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...                     NaN
# 1  Robert Redford, Jennifer Lopez, Morgan Freeman...  Germany, United States
#
#    release_year rating duration listed_in  \
# 0          2021  PG-13  119 min    Dramas
# 1          2005  PG-13  108 min    Dramas
#
#                                        overall_infos
# 0  Movie Worth Sara Colangelo Michael Keaton, Sta...
# 1  Movie An Unfinished Life Lasse Hallström Rober...

# %%
data = ab.groupby("type")["listed_in"].count()
data
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: listed_in, dtype: int64

# %%
sns.barplot(x = data.index,color= 'lightblue',
            y = data. values)

plt.xlabel("Dramas", fontsize = 16)
plt.ylabel("count", fontsize = 16)

plt.title("graph")
plt.show()

# %%
ab[ab["type"]=="Movie"].groupby(["country"]).size().reset_index(name="number of movies")
compare_country=ab[ab["type"]=="Movie"].groupby(["country"]).size().reset_index(name="number of movies").head(5)
sns.barplot(data = compare_country ,
            x="number of movies", y="country")
plt.title("Comparing the movies by Country")
plt.show()

# %%
popular_director=ab.groupby(["director","type"]).size().reset_index(name="number of movies and TV shows")
popular_director.sort_values(by="number of movies and TV shows",ascending=False).head(5).reset_index()
# Out:
#    index                director   type  number of movies and TV shows
# 0   3428           Rajiv Chilaka  Movie                             19
# 1   3479  Raúl Campos, Jan Suter  Movie                             18
# 2   4087             Suhas Kadav  Movie                             16
# 3   2622            Marcus Raboy  Movie                             15
# 4   1803               Jay Karas  Movie                             14

# %%
print(ab.columns)
# Out:
# Index(['type', 'title', 'director', 'cast', 'country', 'release_year',
#        'rating', 'duration', 'listed_in', 'overall_infos'],
#       dtype='object')

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,2,1 )
ab[ab["type"]=="Movie"]['duration'].value_counts().sort_values(ascending=False)[:20].plot(kind="bar",color="coral")
plt.title("Duration of Movies Currently Available on Netflix",fontweight="bold", size=12)

plt.subplot(1,2,2 )
ab[ab["type"]=="TV Show"]['duration'].value_counts().sort_values(ascending=False)[:20].plot(kind="bar",color="Olive")
plt.title("Duration of TV Shows Currently Available on Netflix" ,fontweight="bold", size=12)
plt.show()

# %%
plt.figure(figsize=(8,4))
ab['country'].value_counts().sort_values(ascending=False)[:10].plot(kind="barh",color="Teal")
plt.title('Top 10 Content Producing Countries',fontweight="bold", size=15)
# Out:
# Text(0.5, 1.0, 'Top 10 Content Producing Countries')

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,2,1 )
ab[ab["country"]=="India"]['rating'].value_counts().sort_values(ascending=False)[:20].plot(kind="bar",color="coral")
plt.title("Ratings of Content Produced in India",fontweight="bold", size=12)

plt.subplot(1,2,2 )
ab[ab["country"]=="United States"]['rating'].value_counts().sort_values(ascending=False)[:20].plot(kind="bar",color="Olive")
plt.title("Ratings of Content Produced in United States" ,fontweight="bold", size=12)
plt.show()
